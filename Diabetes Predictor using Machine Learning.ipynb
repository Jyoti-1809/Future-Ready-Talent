# %% [markdown]
# # .............................................Diabetes Predictor.............................................
# # .....................................................By JYOTI.....................................................

# %%
#Import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#Reading the dataset

data = pd.read_csv('diabetes.csv')
data
# Out:
#    Patient Name  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      Abhishek      148             72             35        0  33.6
# 1        Aditya       85             66             29        0  26.6
# 2         Ahmad      183             64              0        0  23.3
# 3        Aladin       89             66             23       94  28.1
# 4          Amar      137             40             35      168  43.1
# ..          ...      ...            ...            ...      ...   ...
# 94     Yatendra      142             82             18       64  24.7
# 95       Yaseer      144             72             27      228  33.9
# 96         Yash       92             62             28        0  31.6
# 97       Yogesh       71             48             18       76  20.4
# 98        Zuheb       93             50             30       64  28.7
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.627   50        1
# ...

# %%
data.shape
# Out:
# (99, 9)

# %%
data.describe()
# Out:
#           Glucose  BloodPressure  SkinThickness     Insulin        BMI  \
# count   99.000000      99.000000      99.000000   99.000000  99.000000
# mean   117.898990      67.848485      19.585859   72.878788  30.807071
# std     33.881695      22.008979      16.082701  126.226980   9.472185
# min      0.000000       0.000000       0.000000    0.000000   0.000000
# 25%     99.000000      64.000000       0.000000    0.000000  25.200000
# 50%    112.000000      72.000000      21.000000    0.000000  31.600000
# 75%    139.000000      80.000000      32.000000  110.000000  37.100000
# max    197.000000     110.000000      60.000000  846.000000  48.800000
#
#        DiabetesPedigreeFunction        Age    Outcome
# count                 99.000000  99.000000  99.000000
# mean                   0.470384  34.454545   0.363636
# std                    0.372773  11.264241   0.483494
# min                    0.102000  21.000000   0.000000
# 25%                    0.248000  25.500000   0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Patient Name              99 non-null     object
#  1   Glucose                   99 non-null     int64
#  2   BloodPressure             99 non-null     int64
#  3   SkinThickness             99 non-null     int64
#  4   Insulin                   99 non-null     int64
#  5   BMI                       99 non-null     float64
#  6   DiabetesPedigreeFunction  99 non-null     float64
#  7   Age                       99 non-null     int64
#  8   Outcome                   99 non-null     int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 7.1+ KB

# %%
data.columns
# Out:
# Index(['Patient Name', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Patient Name                0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#Plotting the distribution of Outcome

sb.countplot(x= 'Outcome', data = data)

# %%
plt.figure(1)
plt.subplot(121), sb.distplot(data['Glucose'])
plt.subplot(122), data['Glucose'].plot.box(figsize=(16,5))
plt.show()

# %%
plt.figure(2)
plt.subplot(121), sb.distplot(data['BloodPressure'])
plt.subplot(122), data['BloodPressure'].plot.box(figsize=(16,5))
plt.show()

# %%
plt.subplot(121), sb.distplot(data['SkinThickness'])
plt.subplot(122), data['SkinThickness'].plot.box(figsize=(16,5))
plt.show()

# %%
plt.subplot(121), sb.distplot(data['Insulin'])
plt.subplot(122), data['Insulin'].plot.box(figsize=(16,5))
plt.show()

# %%
plt.subplot(121), sb.distplot(data['BMI'])
plt.subplot(122), data['BMI'].plot.box(figsize=(16,5))
plt.show()

# %%
plt.subplot(121), sb.distplot(data['DiabetesPedigreeFunction'])
plt.subplot(122), data['DiabetesPedigreeFunction'].plot.box(figsize=(16,5))
plt.show()

# %%
plt.subplot(121), sb.distplot(data['Age'])
plt.subplot(122), data['Age'].plot.box(figsize=(16,5))
plt.show()

# %%
plt.subplot(121), sb.distplot(data['Outcome'])
plt.subplot(122), data['Outcome'].plot.box(figsize=(16,5))
plt.show()

# %%
data.groupby('Outcome')['Glucose'].mean().plot.bar()

# %%
data.groupby('Outcome')['BloodPressure'].mean().plot.bar()

# %%
data.groupby('Outcome')['SkinThickness'].mean().plot.bar()

# %%
data.groupby('Outcome')['Insulin'].mean().plot.bar()

# %%
data.groupby('Outcome')['BMI'].mean().plot.bar()

# %%
data.groupby('Outcome')['DiabetesPedigreeFunction'].mean().plot.bar()

# %%
#Check missing values

data.isnull().sum()
# Out:
# Patient Name                0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
sb.jointplot(x='Glucose',y='Outcome',data=data)

# %%
sb.jointplot(x='BloodPressure',y='Outcome',data=data)

# %%
sb.jointplot(x='SkinThickness',y='Outcome',data=data)

# %%
sb.jointplot(x='Insulin',y='Outcome',data=data)

# %%
sb.jointplot(x='BMI',y='Outcome',data=data)

# %%
sb.jointplot(x='DiabetesPedigreeFunction',y='Outcome',data=data)

# %%
#Check correlations

data.corr()
# Out:
#                            Glucose  BloodPressure  SkinThickness   Insulin  \
# Glucose                   1.000000       0.260753       0.041438  0.442627
# BloodPressure             0.260753       1.000000       0.147449  0.097559
# SkinThickness             0.041438       0.147449       1.000000  0.425063
# Insulin                   0.442627       0.097559       0.425063  1.000000
# BMI                       0.275191       0.390160       0.335926  0.146486
# DiabetesPedigreeFunction  0.219288       0.114240       0.166041  0.078267
# Age                       0.433817       0.411713      -0.003287  0.271179
# Outcome                   0.445147       0.112630       0.087803  0.213907
#
#                                BMI  DiabetesPedigreeFunction       Age  \
# Glucose                   0.275191                  0.219288  0.433817
# BloodPressure             0.390160                  0.114240  0.411713
# SkinThickness             0.335926                  0.166041 -0.003287
# ...

# %%
matrix = data.corr() 
ax = plt.subplots(figsize=(9, 6)), sb.heatmap(matrix, vmax=.8, square=True, cmap="GnBu")

# %%
plt.subplots(figsize=(15,8))
sb.boxplot(x='Age', y='Glucose',data=data)

# %%
plt.subplots(figsize=(15,8))
sb.boxplot(x='Age', y='BloodPressure',data=data)

# %%
plt.subplots(figsize=(15,8))
sb.boxplot(x='Age', y='SkinThickness',data=data)

# %%
plt.subplots(figsize=(15,8))
sb.boxplot(x='Age', y='Insulin',data=data)

# %%
plt.subplots(figsize=(15,8))
sb.boxplot(x='Age', y='BMI',data=data)

# %%
plt.subplots(figsize=(15,8))
sb.boxplot(x='Age', y='DiabetesPedigreeFunction',data=data)

# %%
sb.pairplot(data)

# %%
# Scatter and density plots

def plotScatterMatrix(data, plotSize, textSize):
    data = data.select_dtypes(include =[np.number]) # keep only numerical columns
    
    # Remove rows and columns that would lead to df being singular
    
    data = data.dropna('columns')
    data = data[[col for col in data if data[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(data)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    data = data[columnNames]
    ax = pd.plotting.scatter_matrix(data, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = data.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %%
plotScatterMatrix(data, 15, 10)
